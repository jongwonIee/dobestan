# %%
import pandas as pd

# %%
dfs = pd.read_html("http://finance.naver.com/item/main.nhn?code=005930")

# %%
dfs[3]
# Out:
#        주요재무정보    최근 연간 실적    최근 분기 실적  \
# 0         매출액  2286927.00  2062060.00
# 1        영업이익   367850.00   250251.00
# 2       당기순이익   304748.00   233944.00
# 3       영업이익률       16.08       12.14
# 4        순이익률       13.33       11.34
# 5   ROE(지배주주)       22.80       15.06
# 6        부채비율       42.70       37.08
# 7        당좌비율      173.26      186.84
# 8         유보율    17047.55    19379.48
# 9      EPS(원)   175282.00   135673.00
# 10     BPS(원)   958040.00  1083205.00
# 11   주당배당금(원)    14300.00    20000.00
# 12   시가배당률(%)        1.04        1.51
# 13    배당성향(%)        7.23       13.00
#
#     \n\t\t\t\t\t\t\t\t\t\t2013.12\n\t\t\t\t\t\t\t\t\t  \
# 0                                          2006535.00
# 1                                           264134.00
# 2                                           190601.00
# 3                                               13.16
# 4                                                9.50
# 5                                               11.16
# ...

# %%
# Shell Commands ( ! )

# %%
# pd.read_csv("../../data/2016.csv")["수목명"].unique()
# unique 한 나무이름 만

# %%
# !cat ../../data/2016.csv | cut -d "," -f2 | tail -n +2 | uniq > tree.txt

# %%
# csv ( csvkit )

# %%
# !csvcut -c 2 ../../data/2016.csv

# %%
# 엑셀 ( .csv )

# %%
# Google Finance KOSPI

# %%
# !pip freeze
# Out:
# backports-abc==0.4
# beautifulsoup4==4.5.1
# chardet==2.3.0
# colorama==0.3.7
# command-not-found==0.3
# csvkit==0.9.1
# cycler==0.10.0
# decorator==4.0.10
# entrypoints==0.2.2
# et-xmlfile==1.0.1
# fake-factory==0.7.2
# Faker==0.7.3
# html5lib==0.999999999
# ipykernel==4.5.0
# ipython==5.1.0
# ipython-genutils==0.1.0
# jdcal==1.3
# Jinja2==2.8
# jsonschema==2.5.1
# jupyter-client==4.4.0
# jupyter-core==4.2.0
# jupyterhub==0.6.1
# language-selector==0.1
# lxml==3.6.4
# MarkupSafe==0.23
# matplotlib==1.5.3
# mistune==0.7.3
# mutagen==1.34.1
# mysqlclient==1.3.9
# nbconvert==4.2.0
# nbformat==4.1.0
# nose==1.3.7
# notebook==4.2.3
# numpy==1.11.1
# openpyxl==2.2.0b1
# pamela==0.2.1
# pandas==0.18.1
# path.py==8.2.1
# pexpect==4.2.1
# pickleshare==0.7.4
# Pillow==3.3.1
# prompt-toolkit==1.0.7
# ptyprocess==0.5.1
# py2exe==0.9.2.2
# pycurl==7.19.3
# Pygments==2.1.3
# pygobject==3.12.0
# PyInstaller==3.2
# pymongo==3.3.0
# pyparsing==2.1.9
# PyPDF2==1.26.0
# python-apt===0.9.3.5ubuntu2
# ...
