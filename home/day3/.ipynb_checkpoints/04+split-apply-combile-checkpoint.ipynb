# %%
# The split-apply-combine strategy in data analysis

# R : split-apply-combine
# Pandas: split-apply-combine

# %%
# 1. split ( groupby, get_group )
# 2. apply ( 적용 )
#   2.1. aggregate ( 집계; SUM, MEAN ): 벡터 => 스칼라 ( 특수한 경우 )
#   2.2. transform : 벡터 => 동일한 모양의 벡터, 벡터 => 스칼라 
#   2.3. apply 벡터 => 특수한 모양의 벡터/스칼라 
#   +    filter ( 예, customer_df ; 사람들이 몇 번 구매했는가? ) => 30번 이상 +
#        == HAVING
# 3. combine

# %%
# 어떤 분석 Task => 1. aggregate? 2. transform? 3. apply, 4. filter
#                 1 > 2 > 4 > 1 ...

# %%
import pandas as pd

# %%
payment_df = pd.read_csv("../../data/payment.csv")

# %%
# customer_df.head()

# 유저별 구매액
# 유저별 평균 구매액

# %%
# customer_df.groupby("customer_id")
grouped = payment_df.groupby(payment_df.customer_id)  # DataFrameGroupBy

# %%
# grouped.size() ==> 1. annotate(집계) count(숫자)
#                   [1번유저1번째구매, 1번유저2번째구매, ] => np.count() => size()

# %%
# grouped.first()
# 각각의 그룹에서 첫번째 요소(Row) => DataFrame
# 유저가 구매한 내역 중에서 제일 비싼 내역 1개 씩 뽑자. => sort, first()

# %%
# grouped.last()

# %%
# grouped.sum()["amount"]   # aggregate : np.sum

# %%
# grouped.aggregate("sum")["amount"]

# %%
# import numpy as np
# grouped.aggregate(np.sum)["amount"]

# %%
# grouped.aggregate(  { "amount": "sum"  }  )
# grouped.aggregate(  { "amount": np.sum  }  )

# grouped.aggregate({
#     "amount": ["sum", "mean"],
# })

# grouped.describe()

# %%
# payment_df.describe()

# %%
# %timeit payment_df.groupby("customer_id").aggregate("sum")["amount"].head(3)
# Out:
# 100 loops, best of 3: 2.59 ms per loop

# %%
payment_df.groupby("customer_id")["amount"].aggregate("sum").head(3)
# Out:
# customer_id
# 1    118.68
# 2    128.73
# 3    135.74
# Name: amount, dtype: float64

# %%
# %timeit payment_df["amount"].groupby(payment_df.customer_id).aggregate("sum").head(3)
# Out:
# 1000 loops, best of 3: 1.04 ms per loop

# %%
# Column 을 기준으로 Group By 가 이루어진다.

# %%
# index
# Apple
# Banana
# Cocoa
# Coconut

# %%
df = pd.DataFrame(
    np.random.rand(4, 5),
    index=["Apple", "Banana", "Cocoa", "Coconut"],
)

# %%
df   # 과일의 첫 글자를 기준으로 groupby: ["A", "B", "C"]
# Out:
#                 0         1         2         3         4
# Apple    0.954206  0.010018  0.037200  0.538881  0.596415
# Banana   0.264770  0.945380  0.718019  0.713675  0.534033
# Cocoa    0.036933  0.424636  0.074979  0.161908  0.137396
# Coconut  0.874599  0.205914  0.770304  0.851003  0.653646

# %%
def get_first_char(char):
    return char[0]

# %%
# df.groupby(get_first_char).size()

# %%
df.groupby(lambda x: x[0]).size()
# Out:
# A    1
# B    1
# C    2
# dtype: int64

# %%
df.groupby(lambda x: len(x)).size()
# Out:
# 5    2
# 6    1
# 7    1
# dtype: int64

# %%
# Apple, Banana, Cocoa, Coconut
# Fruit O  O     X       O

# %%
mapping = {
    "Apple": "Fruit",
    "Banana": "Fruit",
    "Cocoa": "Not Fruit",
    "Coconut": "Fruit",
}

# %%
# df.groupby(mapping).size()   # Column, Func(lambda), Dict
df.groupby(
    lambda x: "Fruit" if x in ["Apple", "Banana", "Coconut"] else "Not Fruit"
).size()
# Out:
# Fruit        3
# Not Fruit    1
# dtype: int64

# %%
# 유저의 월별 구매금액 

payment_df["month"] = payment_df.payment_date.apply(lambda x: str(x)[:7])

# %%
# payment_df.groupby(["customer_id", "month"]).size()  === np.count
# payment_df.groupby(["customer_id", "month"]).agg("count")["payment_id"]

# %%
df = pd.DataFrame(
    np.random.randn(4, 4),
    index=list("ABCD"),
)

# df.groupby(lambda x: int(x) % 2 == 0, axis=1).size()

# %%
df.T.groupby(lambda x: int(x) % 2 == 0).size()
# Out:
# False    2
# True     2
# dtype: int64

# %%
# 2. apply
#   2.1. aggregate 
#   2.2. transform

# %%
payment_df     # 칼람 두개를 추가하고 싶어요 
               # => 유저의 총 구매횟수, 유저의 총 구매액 ( ++ )
    
               # payment_df, customer_df JOIN(pd.merge)
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0               1            1         1       76.0    2.99
# 1               2            1         1      573.0    0.99
# 2               3            1         1     1185.0    5.99
# 3               4            1         2     1422.0    0.99
# 4               5            1         2     1476.0    9.99
# 5               6            1         1     1725.0    4.99
# 6               7            1         1     2308.0    4.99
# 7               8            1         2     2363.0    0.99
# 8               9            1         1     3284.0    3.99
# 9              10            1         2     4526.0    5.99
# 10             11            1         1     4611.0    5.99
# 11             12            1         1     5244.0    4.99
# 12             13            1         1     5326.0    4.99
# 13             14            1         1     6163.0    7.99
# 14             15            1         2     7273.0    2.99
# 15             16            1         1     7841.0    4.99
# 16             17            1         2     8033.0    4.99
# 17             18            1         1     8074.0    0.99
# 18             19            1         2     8116.0    0.99
# 19             20            1         2     8326.0    2.99
# 20             21            1         2     9571.0    2.99
# 21             22            1         2    10437.0    4.99
# 22             23            1         2    11299.0    3.99
# 23             24            1         1    11367.0    0.99
# 24             25            1         2    11824.0    4.99
# 25             26            1         1    12250.0    0.99
# 26             27            1         2    13068.0    0.99
# 27             28            1         2    13176.0    2.99
# 28             29            1         1    14762.0    0.99
# 29             30            1         1    14825.0    1.99
# ...           ...          ...       ...        ...     ...
# 16019       16020          598         2     7354.0    0.99
# 16020       16021          598         1     7998.0    0.99
# 16021       16022          598         2     8436.0    0.99
# 16022       16023          598         1     8511.0    5.99
# 16023       16024          598         1     8939.0    4.99
# 16024       16025          598         1    10054.0    4.99
# 16025       16026          598         2    11350.0    0.99
# 16026       16027          598         2    12601.0    2.99
# 16027       16028          598         2    14345.0    0.99
# 16028       16029          598         2    15307.0    2.99
# 16029       16030          598         1    15443.0    7.99
# 16030       16031          599         2     1008.0    4.99
merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     196             raise ValueError(
#     197                 'can not merge DataFrame with instance of '
# --> 198                 'type {0}'.format(type(right)))
#     199
#     200         # warn user when merging between different levels
#
# ValueError: can not merge DataFrame with instance of type <class 'pandas.core.series.Series'>

# %%
temp_df = payment_df["amount"].groupby(payment_df.customer_id).transform("sum")
# transform : vector => vector ( 동일한 사이즈의 벡터 ), 
# [1, 2, 3, 4] => [10, 10, 10, 10]

# %%
# pd.concat(
#     [payment_df, temp_df],
#     axis=1,
# )

# %%
# demean ( 평균에서의 차이 )
# split-apply-combine

# %%
temp_df = payment_df.amount.groupby(payment_df.customer_id).transform(
    lambda x: x - x.mean()
)
temp_df.name = "demeaned amount"
pd.concat([payment_df, temp_df], axis=1)
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0               1            1         1       76.0    2.99
# 1               2            1         1      573.0    0.99
# 2               3            1         1     1185.0    5.99
# 3               4            1         2     1422.0    0.99
# 4               5            1         2     1476.0    9.99
# 5               6            1         1     1725.0    4.99
# 6               7            1         1     2308.0    4.99
# 7               8            1         2     2363.0    0.99
# 8               9            1         1     3284.0    3.99
# 9              10            1         2     4526.0    5.99
# 10             11            1         1     4611.0    5.99
# 11             12            1         1     5244.0    4.99
# 12             13            1         1     5326.0    4.99
# 13             14            1         1     6163.0    7.99
# 14             15            1         2     7273.0    2.99
# 15             16            1         1     7841.0    4.99
# 16             17            1         2     8033.0    4.99
# 17             18            1         1     8074.0    0.99
# 18             19            1         2     8116.0    0.99
# 19             20            1         2     8326.0    2.99
# 20             21            1         2     9571.0    2.99
# 21             22            1         2    10437.0    4.99
# 22             23            1         2    11299.0    3.99
# 23             24            1         1    11367.0    0.99
# 24             25            1         2    11824.0    4.99
# 25             26            1         1    12250.0    0.99
# 26             27            1         2    13068.0    0.99
# 27             28            1         2    13176.0    2.99
# 28             29            1         1    14762.0    0.99
# 29             30            1         1    14825.0    1.99
# ...           ...          ...       ...        ...     ...
# 16019       16020          598         2     7354.0    0.99
# 16020       16021          598         1     7998.0    0.99
# 16021       16022          598         2     8436.0    0.99
# 16022       16023          598         1     8511.0    5.99
# 16023       16024          598         1     8939.0    4.99
# 16024       16025          598         1    10054.0    4.99
# 16025       16026          598         2    11350.0    0.99
# 16026       16027          598         2    12601.0    2.99
# 16027       16028          598         2    14345.0    0.99
# 16028       16029          598         2    15307.0    2.99
# 16029       16030          598         1    15443.0    7.99
# 16030       16031          599         2     1008.0    4.99
# 16031       16032          599         1     2272.0    1.99
# 16032       16033          599         2     3043.0    6.99
# 16033       16034          599         2     3398.0    4.99
# 16034       16035          599         1     3429.0    6.99
# 16035       16036          599         1     5065.0    0.99
# 16036       16037          599         1     5843.0    2.99
# 16037       16038          599         2     6800.0    9.99
# 16038       16039          599         2     6895.0    2.99
# 16039       16040          599         1     8965.0    6.99
# 16040       16041          599         2     9630.0    2.99
# 16041       16042          599         2     9679.0    2.99
# 16042       16043          599         2    11522.0    3.99
# 16043       16044          599         1    14233.0    1.99
