# %%
# 크레딧잡 
# https://kreditjob.com/

# 함수 
# "삼성" => 모든 삼성 계열사 ( 삼성SDS, 삼성전자 )

# %%
# 2. 동적인 사이트! 서버로부터 데이터를 받아온다!
# 크롬 개발자 도구 > Network > All

# 실제 매물정보(리소스)를 가지고 있는 API 를 찾자.

# %%
# ALL => Image, CSS, JS, XHR,...

# AJAX ( Async Javascript and XML ) - XML HTTP Request ( XHR )
# 서버로 부터 데이터를 받아오는(Fetch)

# %%
url = "https://api.zigbang.com/v1/items?detail=true&item_ids=6423394&item_ids=6395815&item_ids=5995433&item_ids=6424758&item_ids=6211301&item_ids=6285114&item_ids=6426548&item_ids=6410702&item_ids=6305853&item_ids=6256852&item_ids=6396121&item_ids=6424508&item_ids=6393377&item_ids=6415633&item_ids=6338386&item_ids=6422447&item_ids=6167680&item_ids=6424804&item_ids=6400219&item_ids=6235949&item_ids=6312690&item_ids=6394232&item_ids=6188763&item_ids=6289652&item_ids=6389364&item_ids=6425232&item_ids=6323511&item_ids=6322440&item_ids=6254050&item_ids=6339438&item_ids=6398176&item_ids=6254961&item_ids=6124173&item_ids=6387858&item_ids=6322281&item_ids=6421010&item_ids=6238499&item_ids=6367887&item_ids=6354071&item_ids=6417467&item_ids=6427351&item_ids=6425246&item_ids=6424318&item_ids=6335211&item_ids=6113664&item_ids=6275936&item_ids=6413574&item_ids=6384007&item_ids=6222912&item_ids=6422507&item_ids=6293543&item_ids=6405725&item_ids=6413261&item_ids=6424746&item_ids=6350223&item_ids=6401349&item_ids=6390306&item_ids=6276404&item_ids=6323525&item_ids=6394144"

# %%
import requests

# %%
response = requests.get(url)

# %%
# response.text  # JSON Format 으로 만들어진 Str
# ========================================> Dict
# 플러그인명: JSONView
# --------------
# 1. [  {"deposit": ___, "rent": ______}, {...} ]
# 2. 연산: 매물의 보증금 합! ( 월세의 합 )

# %%
import json

# %%
# data = json.loads(response.text)
data = response.json()

# %%
data.get("items")[1].get("item").get("rent")
#                 2,3,4
# Out:
# 0

# %%
data = response.json()
data = [
    item.get("item")
    for item
    in data.get("items")
]
data = [
    {
        "deposit": item.get("deposit"),
        "rent": item.get("rent"),
    }
    for item
    in data
]

# %%
len(data)
# Out:
# 60

# %%
from functools import reduce

# %%
deposit_rent_sum = reduce(
    lambda a, b: {
        "deposit": a["deposit"] + b["deposit"],
        "rent": a["rent"] + b["rent"],
    },
    data,
)

# %%
deposit_rent_sum["deposit"] / len(data)
# Out:
# 5488.333333333333

# %%
deposit_rent_sum["rent"] / len(data)
# Out:
# 27.166666666666668

# %%
# .sum()
# .mean()

# %%
# 서비스 개발자 입장에서,

# 0. 로그인 ( 쿠키, 세션 ) / Authorization
# 1. Host, Referer
# 2. Custom Header

# 요기요 -> 모바일(API), 웹 
#         Basic Auth, JWT, Token-based Auth

# ---
# API Client ( Postman . getpostman.com )

# %%
import requests
url = "https://www.yogiyo.co.kr/api/v1/restaurants-geo/?items=20&order=rank&page=0&search=&zip_code=151057"

# %%
headers = {
    "X-ApiKey": "iphoneap",
    "X-ApiSecret": "fe5183cc3dea12bd0ce299cf110a75a2"
}
# Network 탭에서 직접 찾아보세요!

# %%
response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# {'pagination': {'current_page': 0,
#   'per_page': 20,
#   'total_objects': 308,
#   'total_pages': 16},
#  'restaurants': [{'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1598-2',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['분식', '프랜차이즈'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.3963104888636524,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 10476,
#    'is_hotdeal': False,
#    'keywords': '라티놀 안주류 오뎅탕 세트메뉴 세트3（콩라면＋크런치롤반줄） 안주류 계란찜 세트메뉴 세트5（해물라면＋크런치롤반줄） 면류 가쓰오해물우동 세트메뉴 세트4（콩라면＋참치김밥반줄） 안주류 매운양념닭발 세트메뉴 세트9（가쓰오우동＋크런치롤반줄） 분식류 치즈라볶이（2인분） 계절메뉴 사골떡국',
#    'lat': 37.4789635,
#    'list_pos': 1,
#    'lng': 126.9528282,
#    'logo_url': '/media/restaurant_logos/라티놀_20140822_가맹로고_crop_200x200.jpg',
#    'loyal_score': 25.0335284686701,
#    'min_order_amount': 10000,
#    'name': '라티놀 ',
#    'new': False,
#    'new_rating': 1.3220790409740735,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 20:50',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352565867',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200043.383669314,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.11533052039381,
#    'review_count': 711,
#    'review_image_count': 60,
#    'section': 'contract',
#    'section_pos': 1,
#    'slug': '라티놀',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['CESCO', 'excellent'],
#    'takeout': False,
#    'threshold': 7500,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 동작구 상도동 504번지 102호 빙수빙수악마떡볶이',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 14000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 3.0041753328491785,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 233631,
#    'is_hotdeal': False,
#    'keywords': '아부지밥 주류 병맥주（카스） 사이드메뉴 치킨텐더（10조각） 주류 소주（처음처럼） 주류 소주（참이슬） 사이드메뉴 치즈스틱（8조각） 사이드메뉴 버팔로윙（10조각） 사이드메뉴 오뎅탕大 사이드메뉴 치킨텐더（5조각） 파스타메뉴 매운토마토스파게티 사이드메뉴 치즈스틱（4조각）',
#    'lat': 37.4946422,
#    'list_pos': 2,
#    'lng': 126.9575429,
#    'logo_url': '/media/restaurant_logos/아부지밥_20160311_가맹로고이미지약정서_crop_200x200.jpg',
#    'loyal_score': 30.4913034537619,
#    'min_order_amount': 14000,
#    'name': '아부지밥',
#    'new': False,
#    'new_rating': 1.2196521381504761,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 22:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352592891',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200048.701227118,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.01515151515152,
#    'review_count': 132,
#    'review_image_count': 27,
#    'section': 'contract',
#    'section_pos': 2,
#    'slug': '아부지밥',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1655-50',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '분식', '한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 16000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.0590560014230972,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 234661,
#    'is_hotdeal': False,
#    'keywords': '두리닭발 사이드메뉴 얼음황도 추가메뉴 왕문어다리 사이드메뉴 콜라355mL 메인메뉴 오돌뼈大 음료메뉴 사이다355mL 추가메뉴 조개탕 메인메뉴 직화구이닭발통뼈大 음료메뉴 콜라355mL 메인메뉴 위탄불오징어 사이드메뉴 퐁듀',
#    'lat': 37.4751847,
#    'list_pos': 3,
#    'lng': 126.9671755,
#    'logo_url': '/media/restaurant_logos/닭발01_20131128_FoodAD_crop_200x200_piuW1av.jpg',
#    'loyal_score': 17.085538363967,
#    'min_order_amount': 16000,
#    'name': '두리닭발',
#    'new': False,
#    'new_rating': 1.0716103342740606,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '16:00 - 01:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352594014',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200034.555808634,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 4.62162162162162,
#    'review_count': 37,
#    'review_image_count': 11,
#    'section': 'contract',
#    'section_pos': 3,
#    'slug': '두리닭발',
#    'sms_bonus': True,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 7500,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 신림동 1462-42 은행나무오피스텔 601호',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 14000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 3.7861695777188484,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 242338,
#    'is_hotdeal': False,
#    'keywords': '구이랑볶음이-신림점 볶음메뉴 돼지불고기볶음小 볶음메뉴 오징어볶음大 볶음메뉴 오징어볶음小 구이메뉴 고등어구이정식大 볶음메뉴 김치제육볶음大 볶음메뉴 제육볶음小 볶음메뉴 돼지불고기볶음大 사이드메뉴 막국수 사이드메뉴 쌈야채추가 볶음메뉴 고추장삼겹볶음大',
#    'lat': 37.4865396,
#    'list_pos': 4,
#    'lng': 126.9240548,
#    'logo_url': '/media/restaurant_logos/생선구이02_20131128_FoodAD_crop_200x200_I1CY4S5.jpg',
#    'loyal_score': 0.0,
#    'min_order_amount': 14000,
#    'name': '구이랑볶음이-신림점',
#    'new': True,
#    'new_rating': 0.0,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '13:30 - 01:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050712902359',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200011.0,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 1.0,
#    'review_count': 1,
#    'review_image_count': 0,
#    'section': 'contract',
#    'section_pos': 4,
#    'slug': '구이랑볶음이-신림점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 행운동 1674-26 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['중식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 10000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': '2016-11-07T14:00:00',
#    'discount_percent': 10,
#    'discount_until': '2016-11-07T18:59:59.999999',
#    'distance': 1.3590572417381042,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 137,
#    'is_hotdeal': False,
#    'keywords': '다빈(행운동) 요리부 잡탕 요리부 전가복 요리부 해삼탕 요리부 유린기 요리코스 C코스 요리부 부추잡채 요리부 누룽지탕 알뜰세트메뉴 9번세트 요리부 라조기 요리코스 B코스',
#    'lat': 37.4798331,
#    'list_pos': 5,
#    'lng': 126.9581044,
#    'logo_url': '/media/restaurant_logos/탕수육01_20120524_FoodAD_crop_6.jpg',
#    'loyal_score': 7.47663598856371,
#    'min_order_amount': 10000,
#    'name': '다빈(행운동)',
#    'new': False,
#    'new_rating': 0.6272539911949275,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 23:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352561514',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200024.451523207,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.6089552238806,
#    'review_count': 670,
#    'review_image_count': 10,
#    'section': 'contract',
#    'section_pos': 5,
#    'slug': '다빈',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 5000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 888-21 1층 미스몽도시락',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['1인분주문', '일식돈까스', '1인분주문', '한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 5500원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.208755474590927,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 239544,
#    'is_hotdeal': False,
#    'keywords': '미스몽도시락-서울대점 도시락메뉴 황태구이 양식메뉴 수제새우까스 볶음밥메뉴 새우볶음밥 별미메뉴 우볶이 양식메뉴 수제생선까스 양식메뉴 수제치킨까스 우동세트메뉴 우동세트（수제생선까스＋우동） 우동세트메뉴 우동세트（수제새우까스＋우동） 도시락메뉴 소세지야채볶음 별미메뉴 야채죽',
#    'lat': 37.4847926,
#    'list_pos': 6,
#    'lng': 126.9470642,
#    'logo_url': '/media/restaurant_logos/미스몽도시락-서울대점_20160923_가맹로고이미지약정서_crop_200x200.jpg',
#    'loyal_score': 22.7780518774436,
#    'min_order_amount': 5500,
#    'name': '미스몽도시락-서울대점',
#    'new': False,
#    'new_rating': 1.0693709801795586,
#    'one_dish': 1,
#    'open': True,
#    'open_time_description': '10:00 - 20:50',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352599502',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200040.978051877,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 4.0,
#    'review_count': 50,
#    'review_image_count': 7,
#    'section': 'contract',
#    'section_pos': 6,
#    'slug': '미스몽도시락-서울대점',
#    'sms_bonus': True,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 886-17',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '피자양식', '치킨', '프랜차이즈'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 13900원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.0122296940956765,
#    'except_cash': False,
#    'franchise_id': 39,
#    'franchise_name': '(주)디에스푸드 / 피자와치킨의러브레터',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 7777,
#    'is_hotdeal': False,
#    'keywords': '피자와치킨의러브레터-봉천점 CHICKENMENU 양파치킨 CHICKENMENU 양파순살치킨 PIZZA（L）&CHICKENMENU-치킨반마리 스위트더블치킨피자L＋케이준치킨반마리＋콜라1.25L CHICKENMENU 양념치킨 PIZZA（L）&CHICKENMENU-치킨반마리 로얄포테이토피자L＋케이준치킨반마리＋콜라1.25L CHICKENMENU 쏘이치킨（간장맛） PIZZA（M）&CHICKENMENU-치킨한마리 로얄포테이토피자M＋케이준치킨한마리＋콜라500mL PIZZA（L）&CHICKENMENU-치킨반마리 퐁듀피자L＋케이준치킨반마리＋콜라1.25L 추가&음료메뉴 콜라500mL PIZZA（L）&CHICKENMENU-치킨반마리 치즈피자L＋케이준치킨반마리＋콜라1.25L',
#    'lat': 37.4833713,
#    'list_pos': 7,
#    'lng': 126.9484143,
#    'logo_url': '/media/restaurant_logos/피자와치킨의러브레터_20160714_Franchise이미지약정서_crop_200x200_pYag89O.jpg',
#    'loyal_score': 20.8568773398516,
#    'min_order_amount': 13900,
#    'name': '피자와치킨의러브레터-봉천점',
#    'new': False,
#    'new_rating': 1.0318291547749288,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '14:00 - 00:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352570170',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200037.528166878,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.36538461538461,
#    'review_count': 416,
#    'review_image_count': 31,
#    'section': 'contract',
#    'section_pos': 7,
#    'slug': '피자와치킨의러브레터(봉천점)',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1642-2',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 0.9674682114846802,
#    'except_cash': False,
#    'franchise_id': 18,
#    'franchise_name': '(주)GNFOOD(지엔푸드) / 굽네치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 2888,
#    'is_hotdeal': True,
#    'keywords': '굽네치킨-인헌점 <색다른메뉴> 굽네폭립 <굽네양념시리즈> 굽네양념치킨윙 <굽네딥치즈시리즈> 굽네딥치즈윙 <굽네볼케이노쌀떡볶이시리즈> 굽네볼케이노윙＋쌀떡볶이 <굽네볼케이노쌀떡볶이시리즈> 굽네볼케이노통다리＋쌀떡볶이 <굽네반반시리즈> 굽네반반통다리（오리지널통다리반＋볼케이노통다리반） <굽네반반시리즈> 굽네반반윙（굽네오리지널윙반＋볼케이노윙반） <굽네볼케이노모짜렐라시리즈> 굽네볼케이노윙＋모짜렐라치즈 <굽네양념시리즈> 굽네양념치킨 <굽네후르츄소이갈릭시리즈> 굽네후르츄소이갈릭윙',
#    'lat': 37.474278,
#    'list_pos': 8,
#    'lng': 126.966932,
#    'logo_url': '/media/restaurant_logos/굽네치킨_20151119_Franchise이미지약정서_crop_200x200_9t2hNN1.JPG',
#    'loyal_score': 14.4653877149398,
#    'min_order_amount': 15000,
#    'name': '굽네치킨-인헌점',
#    'new': False,
#    'new_rating': 0.985121866300656,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 23:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352584196',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200021.882054382,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#    'review_avg': 4.16417910447761,
#    'review_count': 67,
#    'review_image_count': 7,
#    'section': 'contract',
#    'section_pos': 8,
#    'slug': '굽네치킨-인헌점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['relayo'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': 'http://www.goobne.co.kr/'},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 서초구 서초동 1621-26 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 5.470412831423356,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 242600,
#    'is_hotdeal': False,
#    'keywords': '추풍령묵은지김치찌개 메인메뉴 묵은지김치두부전골 메인메뉴 묵은지참치두부김치찌개 메인메뉴 묵은지김치찜 메인메뉴 묵은지부대전골 메인메뉴 묵은지김치만두전골 메인메뉴 생고기김치찌개 사이드메뉴 공기밥',
#    'lat': 37.4865851,
#    'list_pos': 9,
#    'lng': 127.0170147,
#    'logo_url': '/media/restaurant_logos/김치찌개02_20131128_FoodAD_crop_200x200_UPoHzmm.jpg',
#    'loyal_score': 0.0,
#    'min_order_amount': 15000,
#    'name': '추풍령묵은지김치찌개',
#    'new': True,
#    'new_rating': 0.0,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 09:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050712902650',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200016.0,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 0.0,
#    'review_count': 0,
#    'review_image_count': 0,
#    'section': 'contract',
#    'section_pos': 9,
#    'slug': '추풍령묵은지김치찌개E7SUU7',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 신림동 250-21',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['족발보쌈', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': '2016-11-07T16:00:00',
#    'discount_percent': 10,
#    'discount_until': '2016-11-07T23:59:59.999999',
#    'distance': 1.9690975561231108,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 1504,
#    'is_hotdeal': False,
#    'keywords': '장군왕족발보쌈 추가메뉴 보쌈무속 스페셜（보쌈＋족발）메뉴／（하절기에는굴을사용하지않습니다.） 스페셜（보쌈＋족발）小 식사／쟁반국수 쟁반국수 스페셜（보쌈＋족발）메뉴／（하절기에는굴을사용하지않습니다.） 스페셜（보쌈＋족발）中 스페셜（보쌈＋족발）메뉴／（하절기에는굴을사용하지않습니다.） 스페셜（보쌈＋족발）大 보쌈메뉴 보쌈특大 족발메뉴 족발특大 도시락메뉴 보쌈정식도시락（2人） 추가메뉴 콜라1.25L 보쌈메뉴 보쌈大',
#    'lat': 37.4680554,
#    'list_pos': 10,
#    'lng': 126.9374742,
#    'logo_url': '/media/restaurant_logos/족발01_20120524_FoodAD_crop_11.jpg',
#    'loyal_score': -2.69576299501036,
#    'min_order_amount': 15000,
#    'name': '장군왕족발보쌈',
#    'new': False,
#    'new_rating': 0.09834996897496343,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 03:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352565820',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200014.327726938,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.64,
#    'review_count': 150,
#    'review_image_count': 8,
#    'section': 'contract',
#    'section_pos': 10,
#    'slug': '장군왕족발보쌈',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 금천구 독산동 958-63 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 19000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 5.1545276441588115,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 38351,
#    'is_hotdeal': False,
#    'keywords': '야간매점 쌈밥류 족발쌈밥 탕류／기타 매운떡볶이 쌈밥류 쭈꾸미쌈밥 찜류 묵은지수육찜 쌈밥류 고추장쌈밥 쌈밥류 오징어쌈밥 스페셜메뉴 떡볶이세트（매운세트） 쌈밥류 낙지쌈밥 쌈밥류 오삼쌈밥 쌈밥류 쭈삼쌈밥',
#    'lat': 37.4782197,
#    'list_pos': 11,
#    'lng': 126.9029005,
#    'logo_url': '/media/restaurant_logos/닭볶음탕03_20131128_FoodAD_crop_200x200_10.jpg',
#    'loyal_score': 24.0177707689657,
#    'min_order_amount': 19000,
#    'name': '야간매점',
#    'new': False,
#    'new_rating': 0.9607108307586281,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 09:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352558298',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200041.204466421,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.79846285226302,
#    'review_count': 1171,
#    'review_image_count': 74,
#    'section': 'contract',
#    'section_pos': 11,
#    'slug': '이모네TB276Q',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1584-1',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['야식', '한식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.6487636955443392,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 19545,
#    'is_hotdeal': False,
#    'keywords': '신화불닭(관악구) 음료메뉴 사이다 기본메뉴 닭봉（어깨부위） 반반세트（기본메뉴의2／3양입니다） 반반세트3가지선택 기본메뉴 닭윙（날개부위） 주먹밥메뉴 멸치주먹밥 기본메뉴 양념구이똥집 사이드메뉴 생수 기본메뉴 불꼼장어 사이드메뉴 오뎅탕 주먹밥메뉴 김치주먹밥',
#    'lat': 37.4787861,
#    'list_pos': 12,
#    'lng': 126.9473972,
#    'logo_url': '/media/restaurant_logos/불닭01_20120524_FoodAD_crop_200x200_38.jpg',
#    'loyal_score': 17.2024621065064,
#    'min_order_amount': 15000,
#    'name': '신화불닭(관악구)',
#    'new': False,
#    'new_rating': 0.9583457451513882,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '15:00 - 04:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352553765',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200035.796754216,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 4.30272676683361,
#    'review_count': 1797,
#    'review_image_count': 97,
#    'section': 'contract',
#    'section_pos': 12,
#    'slug': '신화불닭(관악구)',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': True,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1643-5 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['치킨', '프랜차이즈', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.0167376472982876,
#    'except_cash': False,
#    'franchise_id': 37,
#    'franchise_name': '(유)비에이치씨 / BHC치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 218087,
#    'is_hotdeal': True,
#    'keywords': 'BHC-낙성대점 <후라이드> 쏘스에무쵸HOT <후라이드> 쏘스에무쵸 <양념／순살> 치킨강정 <후라이드> 별코치（별에서온코스치킨） <콜라／무／소스> 뿌링뿌링소스 <콜팝> 콜팝치킨 <콜라／무／소스> 커리딥소스 <양념／순살> 순살치킨강정 <콜팝> 미니콜팝 <뿌링클> 바삭클',
#    'lat': 37.4740522999295,
#    'list_pos': 13,
#    'lng': 126.9680474,
#    'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_uetXCQA.JPG',
#    'loyal_score': 13.8353252416379,
#    'min_order_amount': 15000,
#    'name': 'BHC-낙성대점',
#    'new': False,
#    'new_rating': 0.9500654802058586,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 23:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352576215',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200033.224686944,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 4.56544502617801,
#    'review_count': 191,
#    'review_image_count': 43,
#    'section': 'contract',
#    'section_pos': 13,
#    'slug': 'bhc치킨-낙성대점',
#    'sms_bonus': True,
#    'subtitle': '',
#    'tags': ['CESCO'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 인헌동 1636-17',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['일식돈까스'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 20000원 이상',
#    'description': '대표메뉴는 활어회,활어초밥,싱싱해물 입니다.',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 0.9107506526872203,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 42460,
#    'is_hotdeal': False,
#    'keywords': '인헌수산활어회활어초밥전문점 안주류 멍게 안주류 해삼 회메뉴 참돔 추가 콜라（500ml） 안주류 개불 회메뉴 도다리（회） 회메뉴 참숭어 회메뉴 농어 가을메뉴 가을전어 안주류 전복',
#    'lat': 37.4744752,
#    'list_pos': 14,
#    'lng': 126.9655489,
#    'logo_url': '/media/restaurant_logos/회07_20131205_foodon_crop_200x200_10.jpg',
#    'loyal_score': 12.1749497425413,
#    'min_order_amount': 20000,
#    'name': '인헌수산활어회활어초밥전문점',
#    'new': False,
#    'new_rating': 0.904847859164208,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:00 - 23:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352561599',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200030.379677015,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 4.01079136690648,
#    'review_count': 278,
#    'review_image_count': 26,
#    'section': 'contract',
#    'section_pos': 14,
#    'slug': '인헌회초밥전문점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 466-76 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['프랜차이즈', '치킨', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.355246313525189,
#    'except_cash': False,
#    'franchise_id': 18,
#    'franchise_name': '(주)GNFOOD(지엔푸드) / 굽네치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 2884,
#    'is_hotdeal': True,
#    'keywords': '굽네치킨-성현점 <음료메뉴> 보헤미안스파클링（탄산수）-라임350ml <굽네후르츄소이갈릭시리즈> 굽네후르츄소이갈릭윙 <굽네양념시리즈> 굽네양념치킨윙 <굽네양념시리즈> 굽네양념치킨순살 <굽네볼케이노모짜렐라시리즈> 굽네볼케이노윙＋모짜렐라치즈 <색다른메뉴> 굽네불닭발 <사이드메뉴> 굽네웨지／케이준감자¸ <굽네오리지널시리즈> 굽네오리지널윙 <음료메뉴> 콜라245ml <굽네볼케이노쌀떡볶이시리즈> 굽네볼케이노윙＋쌀떡볶이',
#    'lat': 37.4870237,
#    'list_pos': 15,
#    'lng': 126.9488973,
#    'logo_url': '/media/restaurant_logos/굽네치킨_20151119_Franchise이미지약정서_crop_200x200_cm2zsBu.JPG',
#    'loyal_score': 19.3444024787837,
#    'min_order_amount': 15000,
#    'name': '굽네치킨-성현점',
#    'new': False,
#    'new_rating': 0.9027268364463102,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '12:00 - 00:30',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352564462',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200029.862180257,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#    'review_avg': 4.24444444444444,
#    'review_count': 90,
#    'review_image_count': 16,
#    'section': 'contract',
#    'section_pos': 15,
#    'slug': '굽네치킨-성현점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['relayo'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': 'http://www.goobne.co.kr/'},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 금천구 독산동 958-63 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식', '일식돈까스', '분식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 14000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 5.1545276441588115,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 67988,
#    'is_hotdeal': False,
#    'keywords': '식객도시락 한식류 순살윙도시락 한식류 윙봉도시락 스페셜돈까스 스페셜돈까스（생선） 스페셜돈까스 스페셜돈까스（치즈치킨） 스페셜돈까스 스페셜돈까스（등심） 분식류 떡볶이 스페셜메뉴 스페셜메뉴（돈까스＋새우튀김） 돈까스류 미트볼 스페셜메뉴 스페셜메뉴（제육볶음＋새우튀김） 한식류 소갈비정식',
#    'lat': 37.4782197,
#    'list_pos': 16,
#    'lng': 126.9029005,
#    'logo_url': '/media/restaurant_logos/제육정식01_20131128_FoodAD_crop_200x200_raIkK1T.jpg',
#    'loyal_score': 23.4233680300838,
#    'min_order_amount': 14000,
#    'name': '식객도시락',
#    'new': False,
#    'new_rating': 0.7866756538458387,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 09:59',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352564394',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200040.330397907,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.54922279792746,
#    'review_count': 579,
#    'review_image_count': 77,
#    'section': 'contract',
#    'section_pos': 16,
#    'slug': '식객도시락',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['excellent'],
#    'takeout': False,
#    'threshold': 7500,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1589-9번지',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['한식', '야식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 1.3450985835917362,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 217006,
#    'is_hotdeal': False,
#    'keywords': '마초불닭-서울대점 사이드메뉴 오뎅탕 사이드메뉴 쿨피스930mL 사이드메뉴 누룽지탕 기본메뉴 닭볶음탕 사이드메뉴 계란찜 기본메뉴 국물닭발 사이드메뉴 공기밥 세트메뉴 세트2（닭볶음탕＋계란찜＋주먹밥＋쿨피스930mL） 기본메뉴 통뼈닭발 사이드메뉴 주먹밥',
#    'lat': 37.4777041,
#    'list_pos': 17,
#    'lng': 126.9512426,
#    'logo_url': '/media/restaurant_logos/양념닭발01_20131128_FoodAD_crop_200x200_NSx24bR.jpg',
#    'loyal_score': 11.0449805072351,
#    'min_order_amount': 15000,
#    'name': '마초불닭-서울대점',
#    'new': False,
#    'new_rating': 0.7727795035710567,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:30 - 00:50',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352575016',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200029.577202729,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom', 'sms_relay'],
#    'review_avg': 4.23913043478261,
#    'review_count': 92,
#    'review_image_count': 19,
#    'section': 'contract',
#    'section_pos': 17,
#    'slug': '마초불닭-서울대점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 8000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 955-42 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['치킨', '프랜차이즈'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 15000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.864536663251398,
#    'except_cash': False,
#    'franchise_id': 37,
#    'franchise_name': '(유)비에이치씨 / BHC치킨',
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 224181,
#    'is_hotdeal': True,
#    'keywords': 'BHC-봉천스타점 <양념／순살> 매운맛양념치킨 <콜라／무／소스> 뿌링뿌링소스 <콜라／무／소스> 커리딥소스 <뿌링클> 바삭클 <후라이드> 닭날개후라이드 <콜팝> 빅콜팝 <후라이드> 별코치（별에서온코스치킨） <콜팝> 미니콜팝 <뿌링클> 순살바삭클 <양념／순살> 순살떡강정',
#    'lat': 37.4867887,
#    'list_pos': 18,
#    'lng': 126.938005,
#    'logo_url': '/media/restaurant_logos/BHC치킨_20150903_Franchise이미지약정서_crop_200x200_OUXOtng.JPG',
#    'loyal_score': 18.4427670787947,
#    'min_order_amount': 15000,
#    'name': 'BHC-봉천스타점',
#    'new': False,
#    'new_rating': 0.7648033505015084,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '11:59 - 00:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352582351',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200029.993070109,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay', 'relayo_relay'],
#    'review_avg': 4.67836257309941,
#    'review_count': 342,
#    'review_image_count': 83,
#    'section': 'contract',
#    'section_pos': 18,
#    'slug': 'bhc치킨-봉천스타점',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': ['relayo'],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': True,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 관악구 봉천동 1644-5',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['중식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 0.9926473716363329,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': True,
#    'id': 25925,
#    'is_hotdeal': False,
#    'keywords': '향도장-봉천동 요리부 잡채 셋트메뉴 세트8（유산슬＋짜장1＋짬뽕1） 요리부 유산슬 요리부 계란탕 셋트메뉴 세트6（팔보채＋짜장1＋짬뽕1） 요리부 깐풍새우 요리부 라조육 요리부 고기튀김 요리부 잡탕 셋트메뉴 세트6（팔보채＋짜장or짬뽕2）',
#    'lat': 37.4745017,
#    'list_pos': 19,
#    'lng': 126.9670412,
#    'logo_url': '/media/restaurant_logos/짜장면01_20120524_FoodAD_crop_200x200_414.jpg',
#    'loyal_score': 8.87731887596741,
#    'min_order_amount': 12000,
#    'name': '향도장-봉천동',
#    'new': False,
#    'new_rating': 0.7565632807114298,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:00 - 21:00',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050352566943',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200024.230176019,
#    'reachable': True,
#    'relay_methods': ['email', 'box_helicom'],
#    'review_avg': 3.95714285714286,
#    'review_count': 70,
#    'review_image_count': 1,
#    'section': 'contract',
#    'section_pos': 19,
#    'slug': '향도장(인헌동)',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 5000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''},
#   {'additional_discount': 0,
#    'additional_discount_currently_active': False,
#    'additional_discount_per_menu': 0,
#    'address': '서울 동작구 사당동 208-10 1층',
#    'adv_distance': None,
#    'advertisement_rank': 1,
#    'advertisement_type': 'contract',
#    'app_order': True,
#    'can_review': 0,
#    'categories': ['피자양식'],
#    'central_billing': False,
#    'city': '서울',
#    'delivery_fee': 0,
#    'delivery_fee_explanation': '최소 주문 금액 12000원 이상',
#    'description': '',
#    'dine_in': False,
#    'discount_from': None,
#    'discount_percent': 0,
#    'discount_until': None,
#    'distance': 2.308105689368536,
#    'except_cash': False,
#    'franchise_id': None,
#    'franchise_name': None,
#    'free_delivery_threshold': 0,
#    'has_loyalty_support': True,
#    'has_terminal': False,
#    'id': 242228,
#    'is_hotdeal': False,
#    'keywords': '위드커피 샌드위치메뉴 까르보나라샌드위치 티메뉴 애플티（아이레스） 커피메뉴 블루하와이라떼 스무디메뉴 딸기바나나스무디 스무디메뉴 망고요거트스무디 커피메뉴 에스프레소 라떼메뉴 보이티라떼 에이드메뉴 레몬에이드 에이드메뉴 블루베리에이드 스무디메뉴 망고스무디',
#    'lat': 37.4875854,
#    'list_pos': 20,
#    'lng': 126.9672118,
#    'logo_url': '/media/restaurant_logos/커피02_20131128_FoodAD_crop_200x200_iROqUdH.jpg',
#    'loyal_score': 0.0,
#    'min_order_amount': 12000,
#    'name': '위드커피',
#    'new': True,
#    'new_rating': 0.13837886212629283,
#    'one_dish': 0,
#    'open': True,
#    'open_time_description': '10:40 - 20:40',
#    'payment_methods': ['creditcard', 'online'],
#    'phone': '050712902469',
#    'phone_downlisted': False,
#    'phone_order': True,
#    'premium': {},
#    'rating': 200004.0,
#    'reachable': True,
#    'relay_methods': ['email', 'sms_relay'],
#    'review_avg': 0.0,
#    'review_count': 0,
#    'review_image_count': 0,
#    'section': 'contract',
#    'section_pos': 20,
#    'slug': '위드커피',
#    'sms_bonus': False,
#    'subtitle': '',
#    'tags': [],
#    'takeout': False,
#    'threshold': 10000,
#    'thumbnail_message': '',
#    'top100_restaurant': False,
#    'top28': False,
#    'url': ''}]}

# %%
# 1. 정적인 사이트
# 2. 동적인 사이트 
# 3, 4. selenium - integration test ( 브라우저에서 테스트 )

# -----
# numpy.ndarray,
# pandas.Series, pandas.DataFrame
#

# 1. Data Types, 조건문, 반복문, 함수, + Lambda Operator, List Comprehension
# 2. Data 수집하기 => 1. 정적인 사이트, 2. 동적인 사이트 

# 3. Numpy ( 다차원 벡터; 행렬 ) - 이미지 , 영상 
# 4. Pandas ( 엑셀, 시계열 데이터 ) - 주가. 엑셀++

# 5. Matplotlib
# 데이터 분석 프로세스

# %%
from selenium import webdriver

# %%
driver = webdriver.PhantomJS()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/var/pyenv/versions/3.5.1/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      73                                             close_fds=platform.system() != 'Windows',
# ---> 74                                             stdout=self.log_file, stderr=self.log_file)
#      75         except TypeError:
#
# /usr/local/var/pyenv/versions/3.5.1/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     949                                 errread, errwrite,
# --> 950                                 restore_signals, start_new_session)
#     951         except:
#
# /usr/local/var/pyenv/versions/3.5.1/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1543                                 err_msg += ': ' + repr(orig_executable)
# -> 1544                     raise child_exception_type(errno_num, err_msg)
#    1545                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'phantomjs'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-6658ea2466a9> in <module>()
# ----> 1 driver = webdriver.PhantomJS()
#
# /usr/local/var/pyenv/versions/3.5.1/lib/python3.5/site-packages/selenium/webdriver/phantomjs/webdriver.py in __init__(self, executable_path, port, desired_capabilities, service_args, service_log_path)
#      50             service_args=service_args,
#      51             log_path=service_log_path)
# ---> 52         self.service.start()
#      53
#      54         try:
#
# /usr/local/var/pyenv/versions/3.5.1/lib/python3.5/site-packages/selenium/webdriver/common/service.py in start(self)
#      79                 raise WebDriverException(
#      80                     "'%s' executable needs to be in PATH. %s" % (
# ---> 81                         os.path.basename(self.path), self.start_error_message)
#      82                 )
#      83             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'phantomjs' executable needs to be in PATH.

# %%
driver.get("http://naver.com")

# %%
from IPython.display import Image

# %%
driver.get("https://nid.naver.com/nidlogin.login")

# %%
driver.find_element_by_css_selector("#id").send_keys("dobestan")

# %%
Image(driver.get_screenshot_as_png())

# %%
data = data[:5]

# %%
data
# Out:
# [{'deposit': 2000, 'rent': 60},
#  {'deposit': 300, 'rent': 29},
#  {'deposit': 23000, 'rent': 0},
#  {'deposit': 500, 'rent': 55},
#  {'deposit': 1000, 'rent': 44}]

# %%
# 2000 300 23000 500 1000
#     2300 25300 500 1000
# .....

# 파이썬 라이브러리를 이용한 데이터 분석 

# play.dobest.io / tacademy / dkstncks

# $ requests, beautifulsoup4
# $ numpy, pandas

# %%
def temp_func(x, y):
    sum_deposit = x["deposit"] + y["deposit"]
    sum_rent = x["rent"] + y["rent"]
    return {
        "deposit": sum_deposit,
        "rent": sum_rent,
    }

# map, filter, ... , reduce(o o => x)
reduce(
    temp_func,
    data,
)                 # 히스토그램 => {...}
# Out:
# {'deposit': 26800, 'rent': 188}

# %%
deposit_rent_sum = reduce(
    lambda a, b: {
        "deposit": a["deposit"] + b["deposit"],
        "rent": a["rent"] + b["rent"],
    },
    data,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8e737df4e2db> in <module>()
# ----> 1 deposit_rent_sum = reduce(
#       2     lambda a, b: {
#       3         "deposit": a["deposit"] + b["deposit"],
#       4         "rent": a["rent"] + b["rent"],
#       5     },
#
# NameError: name 'reduce' is not defined
